# %%
# for importing personal modules 
import sys
sys.path.insert(0, "D:/Serious Stuff/School/Gonzaga/BMIS 444/Project 3/")
import IPython
from FoodRecipe import FoodRecipe

# %%
FoodRecipe.all_filter_options(category=True)
# Out:
# ['Beef',
#  'Breakfast',
#  'Chicken',
#  'Dessert',
#  'Goat',
#  'Lamb',
#  'Miscellaneous',
#  'Pasta',
#  'Pork',
#  'Seafood',
#  'Side',
#  'Starter',
#  'Vegan',
#  'Vegetarian']

# %%
FoodRecipe.get_filtered_recipes(category="Beef")
# Out:
# {'52874': 'Beef and Mustard Pie',
#  '52878': 'Beef and Oyster pie',
#  '53071': 'Beef Asado',
#  '52997': 'Beef Banh Mi Bowls with Sriracha Mayo, Carrot & Pickled Cucumber',
#  '52904': 'Beef Bourguignon',
#  '52812': 'Beef Brisket Pot Roast',
#  '53070': 'Beef Caldereta',
#  '52873': 'Beef Dumpling Stew',
#  '52952': 'Beef Lo Mein',
#  '53068': 'Beef Mechado',
#  '53053': 'Beef Rendang',
#  '52834': 'Beef stroganoff',
#  '52824': 'Beef Sunday Roast',
#  '52803': 'Beef Wellington',
#  '53013': 'Big Mac',
#  '53069': 'Bistek',
#  '52979': 'Bitterballen (Dutch meatballs)',
#  '52826': 'Braised Beef Chilli',
#  '53055': 'Cevapi Sausages',
#  '53063': 'Chivito uruguayo',
#  '52998': 'Corned Beef and Cabbage',
#  '53058': 'Croatian Bean Stew',
#  '53056': 'Croatian lamb peka',
#  '53031': 'Egyptian Fatteh',
#  '53021': 'Golabki (cabbage roll)',
#  '52781': 'Irish stew',
#  '52938': 'Jamaican Beef Patties',
#  '52947': 'Ma Po Tofu',
#  '52827': 'Massaman Beef curry',
# ...

# %%
FoodRecipe.random_recipe()
# Out:
# {'idMeal': '52964',
#  'strMeal': 'Smoked Haddock Kedgeree',
#  'strMealAlternate': None,
#  'strCategory': 'Breakfast',
#  'strArea': 'Indian',
# ...

# %%
r1 = FoodRecipe(random=True)
print(r1)
# Out:
# {'ID': '52779', 'Name': 'Cream Cheese Tart', 'Category': 'Starter', 'Area': 'American', 'Tags': 'Tart,Savory'}

# %%
r1 = FoodRecipe(search=int(r1.id))
print(r1)
r1 = FoodRecipe(search=r1.name)
print(r1)
# Out:
# {'ID': '52779', 'Name': 'Cream Cheese Tart', 'Category': 'Starter', 'Area': 'American', 'Tags': 'Tart,Savory'}
# {'ID': '52779', 'Name': 'Cream Cheese Tart', 'Category': 'Starter', 'Area': 'American', 'Tags': 'Tart,Savory'}

# %%
r1.ingredient
# Out:
# {'Flour': '250g',
#  'Butter': '125g',
#  'Egg': '1',
#  'Salt': 'Pinch',
#  'Cheese': '300g',
#  'Milk': '100ml milk',
#  'Eggs': '3',
#  'Parmesan Cheese': '100g',
#  'Plum tomatoes': '350g',
#  'White Vinegar': '3tbsp',
#  'Honey': '1 tbsp',
#  'Basil': 'Topping'}

# %%
r1.instructions
# Out:
# ['Crust: make a dough from 250g flour (',
#  'I like mixing different flours like plain and wholegrain spelt flour), 125g butter, 1 egg and a pinch of salt, press it into a tart form and place it in the fridge.',
#  'Filling: stir 300g cream cheese and 100ml milk until smooth, add in 3 eggs, 100g grated parmesan cheese and season with salt, pepper and nutmeg.',
#  'Take the crust out of the fridge and prick the bottom with a fork.',
#  'Pour in the filling and bake at 175 degrees',
#  'C for about 25 minutes.',
#  'Cover the tart with some aluminium foil after half the time.',
#  'In the mean time, slice about 350g mini tomatoes.',
#  'In a small pan heat 3tbsp olive oil, 3tbsp white vinegar, 1 tbsp honey, salt and pepper and combine well.',
#  'Pour over the tomato slices and mix well.',
#  'With a spoon, place the tomato slices on the tart, avoiding too much liquid on it.',
#  'Decorate with basil leaves and enjoy']

# %%
IPython.display.Image(r1.image_url)

# %%
IPython.display.YouTubeVideo(r1.process_url.split("v=")[1])

# %%
r1.save_file()

# %%
r2 = FoodRecipe()
r2.get_random_recipe()
print(r2)
r2.get_recipe(int(r2.id))
print(r2)
r2.get_recipe(r2.name)
print(r2)
# Out:
# {'ID': '52882', 'Name': 'Three Fish Pie', 'Category': 'Seafood', 'Area': 'British', 'Tags': 'Fish,Seafood,Dairy,Pie'}
# {'ID': '52882', 'Name': 'Three Fish Pie', 'Category': 'Seafood', 'Area': 'British', 'Tags': 'Fish,Seafood,Dairy,Pie'}
# {'ID': '52882', 'Name': 'Three Fish Pie', 'Category': 'Seafood', 'Area': 'British', 'Tags': 'Fish,Seafood,Dairy,Pie'}
